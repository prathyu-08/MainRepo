# %%
num1 = 3
num2 = 5
sum_last = num1 + num2
subtract_last = num1 - num2
multiply_last = num1 * num2
divided_last = num1 / num2
modulus_last = num1 % num2
print(f"Sum: {sum_last}")
print(f"Subtract: {subtract_last}")
print(f"Multiply: {multiply_last}")
print(f"Divided: {multiply_last}")
print(f"Modulus: {modulus_last}")
# Out:
# Sum: 8
# Subtract: -2
# Multiply: 15
# Divided: 15
# Modulus: 3

# %%
print(" Hello, World")
# Out:
#  Hello, World

# %%
name = input(" prathyusha: ")
print("08", "name", "vennapusa")
# Out:
#  prathyusha: name
# 08 name vennapusa

# %%
p = "prathyusha"
print(p)

p = "usha"
age = 22
height = 5.2
print(p, age, height)
# Out:
# prathyusha
# usha 22 5.2

# %%
print(" prathyusha ")
# Out:
#  prathyusha

# %%
num = 4
print(num)
# Out:
# 4

# %%
a = 10
b = 3
c= 40
print(a, b,c)
# Out:
# 10 3 40

# %%
s= 10
n=int(s)
m=5.0
f=float(m)
age=22
p=str(age)

print(n)
print(f)
print(p)
# Out:
# 10
# 5.0
# 22
